# %%
from sklearn import datasets
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

os.chdir('C:\\Users\\alexx\\Documents\\thesis\\results')
df = pd.read_csv('features_from_Matrix.csv')
df.shape
# Out:
# (69, 135)

# %% [markdown]
# # 1 Build Random Forest Model With All Features

# %%
from sklearn.model_selection import train_test_split
X=df # Features
X = X.drop('spike',axis=1)
y=df['spike']  # Labels

# %%
from sklearn.ensemble import RandomForestClassifier

feature_names = [f'feature {i}' for i in range(X.shape[1])]
forest = RandomForestClassifier(random_state=0,n_estimators=1000)
forest.fit(X, y)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=0)

# %% [markdown]
# ## 1.1 Feature importance based on mean decrease in impurity
# Gini Importance or Mean Decrease in Impurity (MDI)

# %%
import time
import numpy as np

start_time = time.time()
importances = forest.feature_importances_

feature_imp = pd.Series(importances,index=X.columns)
feature_imp = feature_imp.sort_values(ascending=False)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    print(feature_imp)
# Out:
# Lag1.Brand39                                      0.042569
# keywords_df3057.high                              0.032154
# DiffLag3.ten_thirty_package_number.low            0.027143
# no.high                                           0.027068
# Roll3.other_share.low                             0.022696
# Lag3.cloth.high                                   0.019315
# Lag3.nonwoven_share.high                          0.018904
# Lag2.no.high                                      0.018577
# interval.peak.travel.low                          0.018039
# Lag2.over_thirty_package_number.high              0.018017
# Lag3.other_share.low                              0.017594
# nonwoven.high                                     0.017553
# other_share.low                                   0.017502
# Roll3.yes.high                                    0.017001
# keywords_df7661.high                              0.016894
# Lag1.no.high                                      0.016597
# Lag1.nonwoven.high                                0.016423
# Lag1.Brand22                                      0.015893
# Lag1.regular.high                                 0.015755
# DiffLag3.urethane.low                             0.015316
# yes.high                                          0.015119
# Roll3.nonwoven_share.high                         0.014628
# regular.high                                      0.014612
# Lag2.regular.high                                 0.014486
# Lag3.no_share.high                                0.014411
# keywords_df4471.high                              0.014062
# Brand39                                           0.013958
# Lag1.other_share.low                              0.013813
# keywords_df300                                    0.013768
# Roll3.ten_thirty_package_number.high              0.013551
# keywords_df1736.high                              0.012158
# Lag2.other_share.low                              0.011958
# keywords_df7723.high                              0.011728
# Lag2.cloth.high                                   0.010888
# Lag2.Brand22                                      0.010778
# keywords_df734                                    0.010305
# keywords_df3883                                   0.009687
# DiffRoll3.ten_thirty_package_number.low           0.009550
# DiffLag3.yes.low                                  0.009542
# Lag3.Brand22                                      0.009454
# Lag3.Brand39                                      0.009346
# Roll3.cloth.high                                  0.009305
# Roll3.nonwoven.high                               0.009217
# keywords_df3150.low                               0.009176
# keywords_df1231.high                              0.009106
# keywords_df4473.low                               0.009099
# keywords_df1829.low                               0.008823
# Roll3.interval.peak.travel.low                    0.008753
# keywords_df2560                                   0.008604
# interval.peak.law..govt.and.politics.high         0.008530
# Lag1.gauze_share.low                              0.008107
# Roll3.epidemic.high                               0.008071
# nonwoven_share.high                               0.008055
# DiffLag2.three_ten_package_number.low             0.008046
# X.health.and.fitness.disease                      0.007970
# keywords_df2995.high                              0.007475
# Lag2.nonwoven_share.high                          0.007402
# keywords_df3450                                   0.006975
# keywords_df7311.low                               0.006833
# Lag1.health.and.fitness.high                      0.006510
# DiffLag2.smaller.low                              0.006475
# Lag1.Brand32                                      0.005848
# DiffLag3.three_ten_package_number.low             0.005778
# Lag2.no_share.high                                0.005760
# Lag3.Brand31                                      0.005415
# disease.high                                      0.005201
# Lag2.Brand32                                      0.004959
# keywords_df4771                                   0.004588
# keywords_df1736.low                               0.004489
# Lag1.nonwoven_share.high                          0.004405
# DiffLag3.zero_three_package_number.low            0.004284
# Lag2..health.and.fitness.disease                  0.004088
# Lag2.urethane.high                                0.004086
# Lag3.nonwoven.high                                0.003909
# Lag1.kids.high                                    0.003888
# interval.peak.shows.and.events.low                0.003860
# Lag2.interval.peak.travel.low                     0.003842
# three_ten_package_number.high                     0.003766
# Lag2.yes.high                                     0.003749
# keywords_df7156.low                               0.003710
# Lag2.bigger.high                                  0.003650
# keywords_df1051.high                              0.003420
# Lag2..health.and.fitness.disease.epidemic         0.003388
# DiffLag3.other.low                                0.003346
# Lag3..health.and.fitness.disease                  0.003329
# zero_three_package_number.high                    0.003325
# bigger.high                                       0.003109
# DiffLag2.yes.low                                  0.003020
# Lag2.ten_thirty_package_number.high               0.003012
# kids.high                                         0.002925
# Lag1.cloth.high                                   0.002874
# Lag2.disease.high                                 0.002696
# Lag1.interval.peak.law..govt.and.politics.high    0.002660
# Lag1.yes.high                                     0.002415
# Lag2.health.and.fitness.high                      0.002345
# Lag3.Brand45                                      0.002194
# Lag1.disease.high                                 0.002163
# Lag1..health.and.fitness.disease                  0.002089
# Lag2.interval.peak.disease.low                    0.001794
# Roll3.disease.high                                0.001693
# Lag3.interval.peak.shopping.high                  0.001692
# Roll3.health.and.fitness.high                     0.001582
# Lag3.bigger.high                                  0.001498
# Lag1..health.and.fitness.disease.epidemic         0.001485
# keywords_df4318.high                              0.001458
# keywords_df7218.low                               0.001452
# keywords_df1674.high                              0.001430
# keywords_df2.low                                  0.001419
# keywords_df3148.high                              0.001416
# Roll3.interval.peak.shows.and.events.low          0.001337
# keywords_df5050                                   0.001090
# DiffLag3.smaller.low                              0.001084
# Lag1.bigger.high                                  0.001050
# keywords_df3829                                   0.000980
# keywords_df1556.high                              0.000747
# keywords_df7961.high                              0.000661
# keywords_df7523.high                              0.000650
# Lag3.urethane.high                                0.000583
# Lag3..health.and.fitness.disease.epidemic         0.000581
# Lag3.interval.peak.travel.low                     0.000556
# keywords_df2506                                   0.000540
# keywords_df5796.low                               0.000505
# keywords_df8228.high                              0.000481
# Roll3.gauze.high                                  0.000480
# keywords_df8303.high                              0.000478
# Lag3.Brand32                                      0.000460
# Lag2.zero_three_package_number.high               0.000399
# gauze.high                                        0.000393
# keywords_df7535.high                              0.000353
# Lag2.Brand45                                      0.000222
# keywords_df8228.low                               0.000215
# keywords_df680                                    0.000213
# Lag3.ten_thirty_package_number.high               0.000093
# keywords_df8303.low                               0.000000
# dtype: float64

# %% [markdown]
# ## 1.2 Feature importance based on feature permutation
#  Permutation Importance or Mean Decrease in Accuracy (MDA)

# %%
from sklearn.inspection import permutation_importance
result = permutation_importance(forest, X, y, n_repeats=10, random_state=42, n_jobs=2)
forest_imp = pd.Series(result.importances_mean, index=X.columns)
forest_imp = forest_imp.sort_values(ascending=False)

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    print(forest_imp)
# Out:
# bigger.high                                       0.0
# Lag2.interval.peak.disease.low                    0.0
# Lag3.bigger.high                                  0.0
# Lag3..health.and.fitness.disease.epidemic         0.0
# Lag3..health.and.fitness.disease                  0.0
# Lag2.zero_three_package_number.high               0.0
# Lag2.yes.high                                     0.0
# Lag2.urethane.high                                0.0
# Lag2.ten_thirty_package_number.high               0.0
# Lag2.regular.high                                 0.0
# Lag2.over_thirty_package_number.high              0.0
# Lag2.other_share.low                              0.0
# Lag2.nonwoven_share.high                          0.0
# Lag2.no_share.high                                0.0
# Lag2.no.high                                      0.0
# Lag2.interval.peak.travel.low                     0.0
# Lag2.health.and.fitness.high                      0.0
# Lag3.Brand31                                      0.0
# Lag2.disease.high                                 0.0
# Lag2.cloth.high                                   0.0
# Lag2.Brand45                                      0.0
# Lag2.Brand32                                      0.0
# Lag2.Brand22                                      0.0
# Lag2.bigger.high                                  0.0
# Lag2..health.and.fitness.disease.epidemic         0.0
# Lag2..health.and.fitness.disease                  0.0
# Lag1.yes.high                                     0.0
# Lag1.regular.high                                 0.0
# Lag1.other_share.low                              0.0
# Lag1.nonwoven_share.high                          0.0
# Lag1.nonwoven.high                                0.0
# Lag1.no.high                                      0.0
# Lag3.Brand22                                      0.0
# Lag3.Brand32                                      0.0
# Brand39                                           0.0
# Roll3.cloth.high                                  0.0
# yes.high                                          0.0
# X.health.and.fitness.disease                      0.0
# three_ten_package_number.high                     0.0
# Roll3.yes.high                                    0.0
# Roll3.ten_thirty_package_number.high              0.0
# Roll3.other_share.low                             0.0
# Roll3.nonwoven_share.high                         0.0
# Roll3.nonwoven.high                               0.0
# Roll3.interval.peak.travel.low                    0.0
# Roll3.interval.peak.shows.and.events.low          0.0
# Roll3.health.and.fitness.high                     0.0
# Roll3.gauze.high                                  0.0
# Roll3.epidemic.high                               0.0
# Roll3.disease.high                                0.0
# regular.high                                      0.0
# Lag3.Brand39                                      0.0
# other_share.low                                   0.0
# nonwoven_share.high                               0.0
# nonwoven.high                                     0.0
# no.high                                           0.0
# Lag3.urethane.high                                0.0
# Lag3.ten_thirty_package_number.high               0.0
# Lag3.other_share.low                              0.0
# Lag3.nonwoven_share.high                          0.0
# Lag3.nonwoven.high                                0.0
# Lag3.no_share.high                                0.0
# Lag3.interval.peak.travel.low                     0.0
# Lag3.interval.peak.shopping.high                  0.0
# Lag3.cloth.high                                   0.0
# Lag3.Brand45                                      0.0
# Lag1.kids.high                                    0.0
# Lag1.interval.peak.law..govt.and.politics.high    0.0
# Lag1.health.and.fitness.high                      0.0
# interval.peak.travel.low                          0.0
# keywords_df3148.high                              0.0
# keywords_df3057.high                              0.0
# keywords_df300                                    0.0
# keywords_df2995.high                              0.0
# keywords_df2560                                   0.0
# keywords_df2506                                   0.0
# keywords_df2.low                                  0.0
# keywords_df1829.low                               0.0
# keywords_df1736.low                               0.0
# keywords_df1736.high                              0.0
# keywords_df1674.high                              0.0
# keywords_df1556.high                              0.0
# keywords_df1231.high                              0.0
# keywords_df1051.high                              0.0
# interval.peak.shows.and.events.low                0.0
# Lag1.gauze_share.low                              0.0
# interval.peak.law..govt.and.politics.high         0.0
# gauze.high                                        0.0
# disease.high                                      0.0
# DiffRoll3.ten_thirty_package_number.low           0.0
# DiffLag3.zero_three_package_number.low            0.0
# DiffLag3.yes.low                                  0.0
# DiffLag3.urethane.low                             0.0
# DiffLag3.three_ten_package_number.low             0.0
# DiffLag3.ten_thirty_package_number.low            0.0
# DiffLag3.smaller.low                              0.0
# DiffLag3.other.low                                0.0
# DiffLag2.yes.low                                  0.0
# DiffLag2.three_ten_package_number.low             0.0
# DiffLag2.smaller.low                              0.0
# keywords_df3150.low                               0.0
# keywords_df3450                                   0.0
# keywords_df3829                                   0.0
# keywords_df3883                                   0.0
# Lag1.disease.high                                 0.0
# Lag1.cloth.high                                   0.0
# Lag1.Brand39                                      0.0
# Lag1.Brand32                                      0.0
# Lag1.Brand22                                      0.0
# Lag1.bigger.high                                  0.0
# Lag1..health.and.fitness.disease.epidemic         0.0
# Lag1..health.and.fitness.disease                  0.0
# kids.high                                         0.0
# keywords_df8303.low                               0.0
# keywords_df8303.high                              0.0
# keywords_df8228.low                               0.0
# keywords_df8228.high                              0.0
# keywords_df7961.high                              0.0
# keywords_df7723.high                              0.0
# keywords_df7661.high                              0.0
# keywords_df7535.high                              0.0
# keywords_df7523.high                              0.0
# keywords_df734                                    0.0
# keywords_df7311.low                               0.0
# keywords_df7218.low                               0.0
# keywords_df7156.low                               0.0
# keywords_df680                                    0.0
# keywords_df5796.low                               0.0
# keywords_df5050                                   0.0
# keywords_df4771                                   0.0
# keywords_df4473.low                               0.0
# keywords_df4471.high                              0.0
# keywords_df4318.high                              0.0
# zero_three_package_number.high                    0.0
# dtype: float64

# %% [markdown]
# # 2 Random Forest with Selected Features
# choose features with imp>0.015, and delete "Lag3.other_share.low" "Roll3.other_share.low" (because there are many similar features).

# %%
df2 = df.filter(['Lag1.Brand39','spike','Lag3.nonwoven_share.high'
                 'keywords_df3057.high',
                 'DiffLag3.ten_thirty_package_number.low',
                'no.high','Lag3.cloth.high','Lag3.nonwoven_share.high',
                 'Lag2.no.high','interval.peak.travel.low','Lag2.over_thirty_package_number.high',
                 'other_share.low','Roll3.yes.high','keywords_df7661.high','Lag1.no.high ','Lag1.nonwoven.high   '
                ], axis=1)
df2.shape
# Out:
# (69, 12)

# %%
# add date into dataset for making plots later 
os.chdir('C:\\Users\\alexx\\Documents\\thesis\\processed data')
df_date = pd.read_csv('Other_variables.csv')
df2['date'] = df_date['date']

# %% [markdown]
# ## 2.1 Training and Testing Data

# %%
from sklearn.model_selection import train_test_split
X=df2.drop('spike',axis=1) # Features
y=df2['spike']  # Labels
    
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train_with_date = X_train
X_test_with_date = X_test

X_train = X_train.drop('date',axis=1)
X_test = X_test.drop('date',axis=1)

# %% [markdown]
# ## 2.2 Build Model

# %%
from sklearn.ensemble import RandomForestClassifier

feature_names = [f'feature {i}' for i in range(X.shape[1])]
forest = RandomForestClassifier(random_state=0)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# ## 2.3 Feature importance based on mean decrease in impurity
# Gini Importance or Mean Decrease in Impurity (MDI)

# %%
# test hong long will it take to calculate features importance
import time
import numpy as np

start_time = time.time()
importances = forest.feature_importances_
std = np.std([
    tree.feature_importances_ for tree in forest.estimators_], axis=0)
elapsed_time = time.time() - start_time

print(f"Elapsed time to compute the importances: "
      f"{elapsed_time:.3f} seconds")
# Out:
# Elapsed time to compute the importances: 0.007 seconds

# %%
feature_imp = pd.Series(importances,index=X_train.columns)
feature_imp = feature_imp.sort_values(ascending=False)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    print(feature_imp)
# Out:
# Lag3.cloth.high                           0.138394
# DiffLag3.ten_thirty_package_number.low    0.137795
# Lag1.Brand39                              0.130804
# Lag3.nonwoven_share.high                  0.104953
# Roll3.yes.high                            0.101788
# no.high                                   0.080052
# other_share.low                           0.070677
# interval.peak.travel.low                  0.070122
# Lag2.over_thirty_package_number.high      0.066265
# Lag2.no.high                              0.050615
# keywords_df7661.high                      0.048536
# dtype: float64

# %% [markdown]
# ## 2.4 Plot Importance

# %%
import seaborn as sns

# %matplotlib inline
# Creating a bar plot
plt.figure(figsize=(50, 25))
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score', size=55)
plt.ylabel('Features', size=55)
plt.title("Visualizing Important Features", size=45)

plt.xticks(fontsize=45)
plt.yticks(fontsize=45)


plt.show()

# %%
fig, ax = plt.subplots()
feature_imp.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI", size=25)
ax.set_ylabel("Mean decrease in impurity", size=15)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %% [markdown]
# ## 2.5 Plot Validation Result

# %%
# Use datetime for creating date objects for plotting
import datetime

y_pred=forest.predict(X_test)


# Dataframe with predictions and dates
predictions_data = pd.DataFrame(data = {'prediction': y_pred})
# Plot the actual values
plt.figure(figsize=(20, 10))
plt.plot(df_date['date'], df['spike'], 'bo', label = 'actual')
# Plot the predicted values
plt.plot(X_test_with_date['date'],predictions_data['prediction'], 'ro', label = 'prediction')
plt.xticks(rotation = '60', size=5); 
plt.legend()
# Graph labels
plt.xlabel('Date'); plt.ylabel('Maximum Temperature (F)'); plt.title('Actual and Predicted Values');

# %% [markdown]
# ## 2.6 Confusion Matrix, Accuracy, ROC, and AUC

# %%
# out-of-sample
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[18,  0],
#        [ 0,  3]], dtype=int64)

# %%
#in-sample
from sklearn.metrics import confusion_matrix
y_predin=forest.predict(X_train)
confusion_matrix(y_train, y_predin)
# Out:
# array([[42,  0],
#        [ 0,  6]], dtype=int64)

# %%
# calculate out-of-sample accuracy
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
# calculate in-sample accuracy
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_train, y_predin))
# Out:
# Accuracy: 1.0

# %%
from sklearn.svm import SVC
from sklearn.metrics import plot_roc_curve

# SVC - Support Vector Classification

svc = SVC(random_state=42)
svc.fit(X_train, y_train)

svc_disp = plot_roc_curve(svc, X_test, y_test)
plt.show()

# %%
forest.fit(X_train, y_train)
ax = plt.gca()
forest_disp = plot_roc_curve(forest, X_test, y_test, ax=ax, alpha=0.8)
svc_disp.plot(ax=ax, alpha=0.8)
plt.show()
